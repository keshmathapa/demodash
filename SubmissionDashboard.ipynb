# %% [markdown]
# # Keshma's Covid-19 Dashboard

# %% [markdown]
# This is a template for your DIY Covid Dashboard, which shows the data for England's new cases and number of PCR tests conducted on a particular date.

# %%
from IPython.display import clear_output
import ipywidgets as wdg
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import json
from uk_covid19 import Cov19API

# %%
pip install voila==0.3.0a2
# Out:
# Collecting voila==0.3.0a2
#   Downloading voila-0.3.0a2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 27.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: jupyter-client<8,>=6.1.3 in /opt/conda/lib/python3.10/site-packages (from voila==0.3.0a2) (7.3.4)
# Requirement already satisfied: websockets>=9.0 in /opt/conda/lib/python3.10/site-packages (from voila==0.3.0a2) (10.3)
# Requirement already satisfied: jupyter-server<2.0.0,>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from voila==0.3.0a2) (1.18.1)
# Requirement already satisfied: nbconvert<7,>=6.0.0 in /opt/conda/lib/python3.10/site-packages (from voila==0.3.0a2) (6.5.3)
# Requirement already satisfied: nbclient<0.6,>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from voila==0.3.0a2) (0.5.13)
# Requirement already satisfied: tornado>=6.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (6.1)
# Requirement already satisfied: traitlets in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (5.3.0)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (1.5.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (2.8.2)
# Requirement already satisfied: jupyter-core>=4.9.2 in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (4.11.1)
# Requirement already satisfied: pyzmq>=23.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (23.2.1)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client<8,>=6.1.3->voila==0.3.0a2) (0.4)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (3.1.2)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (1.4.1)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (0.14.1)
# Requirement already satisfied: Send2Trash in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (0.15.0)
# Requirement already satisfied: nbformat>=5.2.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (5.4.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (21.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (21.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (3.6.1)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (5.0.1)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (4.11.1)
# Requirement already satisfied: tinycss2 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (1.1.1)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (0.7.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (2.1.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (2.13.0)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (0.2.2)
# Requirement already satisfied: lxml in /opt/conda/lib/python3.10/site-packages (from nbconvert<7,>=6.0.0->voila==0.3.0a2) (4.9.1)
# Requirement already satisfied: idna>=2.8 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (3.3)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (1.3.0)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (4.15.0)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat>=5.2.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (2.16.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client<8,>=6.1.3->voila==0.3.0a2) (1.16.0)
# Requirement already satisfied: ptyprocess in /opt/conda/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (21.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->nbconvert<7,>=6.0.0->voila==0.3.0a2) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert<7,>=6.0.0->voila==0.3.0a2) (0.5.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (3.0.9)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat>=5.2.0->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (22.1.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (1.15.1)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<2.0.0,>=0.3.0->voila==0.3.0a2) (2.21)
# Installing collected packages: voila
#   Attempting uninstall: voila
#     Found existing installation: voila 0.3.6
#     Uninstalling voila-0.3.6:
# ERROR: Could not install packages due to an OSError: [Errno 13] Permission denied: '/opt/conda/etc/jupyter/jupyter_notebook_config.d/voila.json'
# Consider using the `--user` option or check the permissions.
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# %matplotlib inline
# make figures larger
plt.rcParams['figure.dpi'] = 100

# %% [markdown]
# ## Load initial data from disk
#
# The data in the initial .json file is load below:

# %%
with open("Englandnewcasesandtests.json", "rt") as INFILE: 
    jsondata = json.load(INFILE)

# %%
data_list = jsondata['data']
data_list
# Out:
# [{'date': '2022-12-01',
#   'NewCasesByPublishDate': 22375,
#   'PCRTestsByPublishDate': None},
#  {'date': '2022-11-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': None},
#  {'date': '2022-11-29',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173358841},
#  {'date': '2022-11-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173337231},
#  {'date': '2022-11-27',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173319956},
#  {'date': '2022-11-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173306678},
#  {'date': '2022-11-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173290401},
#  {'date': '2022-11-24',
#   'NewCasesByPublishDate': 20261,
#   'PCRTestsByPublishDate': 173272799},
#  {'date': '2022-11-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173240581},
#  {'date': '2022-11-22',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173216513},
#  {'date': '2022-11-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173194249},
#  {'date': '2022-11-20',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173176676},
#  {'date': '2022-11-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173163293},
#  {'date': '2022-11-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173148828},
#  {'date': '2022-11-17',
#   'NewCasesByPublishDate': 20866,
#   'PCRTestsByPublishDate': 173129924},
#  {'date': '2022-11-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173099215},
#  {'date': '2022-11-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173074668},
#  {'date': '2022-11-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173051254},
#  {'date': '2022-11-13',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173033225},
#  {'date': '2022-11-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173019064},
#  {'date': '2022-11-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 173000854},
#  {'date': '2022-11-10',
#   'NewCasesByPublishDate': 21391,
#   'PCRTestsByPublishDate': 172979438},
#  {'date': '2022-11-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172946820},
#  {'date': '2022-11-08',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172922934},
#  {'date': '2022-11-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172896986},
#  {'date': '2022-11-06',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172880586},
#  {'date': '2022-11-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172866556},
#  {'date': '2022-11-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172846892},
#  {'date': '2022-11-03',
#   'NewCasesByPublishDate': 28209,
#   'PCRTestsByPublishDate': 172823788},
#  {'date': '2022-11-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172783889},
#  {'date': '2022-11-01',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172761581},
#  {'date': '2022-10-31',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172733801},
#  {'date': '2022-10-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172715417},
#  {'date': '2022-10-29',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172700084},
#  {'date': '2022-10-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172678786},
#  {'date': '2022-10-27',
#   'NewCasesByPublishDate': 39178,
#   'PCRTestsByPublishDate': 172653564},
#  {'date': '2022-10-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172616985},
#  {'date': '2022-10-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172586841},
#  {'date': '2022-10-24',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172554301},
#  {'date': '2022-10-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172535709},
#  {'date': '2022-10-22',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172505906},
#  {'date': '2022-10-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172483784},
#  {'date': '2022-10-20',
#   'NewCasesByPublishDate': 52672,
#   'PCRTestsByPublishDate': 172459433},
#  {'date': '2022-10-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172432488},
#  {'date': '2022-10-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172397130},
#  {'date': '2022-10-17',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172364399},
#  {'date': '2022-10-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172344142},
#  {'date': '2022-10-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172324995},
#  {'date': '2022-10-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172298506},
#  {'date': '2022-10-13',
#   'NewCasesByPublishDate': 59101,
#   'PCRTestsByPublishDate': 172270590},
#  {'date': '2022-10-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172243038},
#  {'date': '2022-10-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172212785},
#  {'date': '2022-10-10',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172180783},
#  {'date': '2022-10-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172159745},
#  {'date': '2022-10-08',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172140927},
#  {'date': '2022-10-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172116783},
#  {'date': '2022-10-06',
#   'NewCasesByPublishDate': 58832,
#   'PCRTestsByPublishDate': 172089946},
#  {'date': '2022-10-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172062020},
#  {'date': '2022-10-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172032199},
#  {'date': '2022-10-03',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 172003823},
#  {'date': '2022-10-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171987055},
#  {'date': '2022-10-01',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171969346},
#  {'date': '2022-09-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171947664},
#  {'date': '2022-09-29',
#   'NewCasesByPublishDate': 46853,
#   'PCRTestsByPublishDate': 171923224},
#  {'date': '2022-09-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171900778},
#  {'date': '2022-09-27',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171873438},
#  {'date': '2022-09-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171849103},
#  {'date': '2022-09-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171831485},
#  {'date': '2022-09-24',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171814450},
#  {'date': '2022-09-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171795501},
#  {'date': '2022-09-22',
#   'NewCasesByPublishDate': 33497,
#   'PCRTestsByPublishDate': 171773042},
#  {'date': '2022-09-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171735311},
#  {'date': '2022-09-20',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171712694},
#  {'date': '2022-09-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171691946},
#  {'date': '2022-09-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171678211},
#  {'date': '2022-09-17',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171663799},
#  {'date': '2022-09-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171645095},
#  {'date': '2022-09-15',
#   'NewCasesByPublishDate': 27055,
#   'PCRTestsByPublishDate': 171624565},
#  {'date': '2022-09-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171604636},
#  {'date': '2022-09-13',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171580739},
#  {'date': '2022-09-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171557262},
#  {'date': '2022-09-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171535816},
#  {'date': '2022-09-10',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171519403},
#  {'date': '2022-09-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171498249},
#  {'date': '2022-09-08',
#   'NewCasesByPublishDate': 28258,
#   'PCRTestsByPublishDate': 171473386},
#  {'date': '2022-09-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171433336},
#  {'date': '2022-09-06',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171404312},
#  {'date': '2022-09-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171374919},
#  {'date': '2022-09-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171347956},
#  {'date': '2022-09-03',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171325964},
#  {'date': '2022-09-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171300134},
#  {'date': '2022-09-01',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171268507},
#  {'date': '2022-08-31',
#   'NewCasesByPublishDate': 24908,
#   'PCRTestsByPublishDate': 171223052},
#  {'date': '2022-08-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171186568},
#  {'date': '2022-08-29',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171153384},
#  {'date': '2022-08-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171127133},
#  {'date': '2022-08-27',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171103420},
#  {'date': '2022-08-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171072004},
#  {'date': '2022-08-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 171040330},
#  {'date': '2022-08-24',
#   'NewCasesByPublishDate': 27732,
#   'PCRTestsByPublishDate': 170983525},
#  {'date': '2022-08-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170942446},
#  {'date': '2022-08-22',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170906159},
#  {'date': '2022-08-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170872505},
#  {'date': '2022-08-20',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170845228},
#  {'date': '2022-08-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170810493},
#  {'date': '2022-08-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170778248},
#  {'date': '2022-08-17',
#   'NewCasesByPublishDate': 35168,
#   'PCRTestsByPublishDate': 170728407},
#  {'date': '2022-08-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170686243},
#  {'date': '2022-08-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170642007},
#  {'date': '2022-08-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170607383},
#  {'date': '2022-08-13',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170579302},
#  {'date': '2022-08-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170545170},
#  {'date': '2022-08-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170504013},
#  {'date': '2022-08-10',
#   'NewCasesByPublishDate': 46284,
#   'PCRTestsByPublishDate': 170450881},
#  {'date': '2022-08-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170408480},
#  {'date': '2022-08-08',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170323426},
#  {'date': '2022-08-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170288980},
#  {'date': '2022-08-06',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170260446},
#  {'date': '2022-08-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170222962},
#  {'date': '2022-08-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170182106},
#  {'date': '2022-08-03',
#   'NewCasesByPublishDate': 57277,
#   'PCRTestsByPublishDate': 170128599},
#  {'date': '2022-08-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170082130},
#  {'date': '2022-08-01',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 170034359},
#  {'date': '2022-07-31',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169996939},
#  {'date': '2022-07-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169966219},
#  {'date': '2022-07-29',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169928579},
#  {'date': '2022-07-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169882149},
#  {'date': '2022-07-27',
#   'NewCasesByPublishDate': 81951,
#   'PCRTestsByPublishDate': 169824945},
#  {'date': '2022-07-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169771389},
#  {'date': '2022-07-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169716933},
#  {'date': '2022-07-24',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169677689},
#  {'date': '2022-07-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169642368},
#  {'date': '2022-07-22',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169600907},
#  {'date': '2022-07-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169545035},
#  {'date': '2022-07-20',
#   'NewCasesByPublishDate': 123568,
#   'PCRTestsByPublishDate': 169468823},
#  {'date': '2022-07-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169407733},
#  {'date': '2022-07-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169359507},
#  {'date': '2022-07-17',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169310039},
#  {'date': '2022-07-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169271673},
#  {'date': '2022-07-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169226645},
#  {'date': '2022-07-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169175610},
#  {'date': '2022-07-13',
#   'NewCasesByPublishDate': 171877,
#   'PCRTestsByPublishDate': 169096523},
#  {'date': '2022-07-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 169042833},
#  {'date': '2022-07-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168973899},
#  {'date': '2022-07-10',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168930634},
#  {'date': '2022-07-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168879328},
#  {'date': '2022-07-08',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168834816},
#  {'date': '2022-07-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168797240},
#  {'date': '2022-07-06',
#   'NewCasesByPublishDate': 120170,
#   'PCRTestsByPublishDate': 168720393},
#  {'date': '2022-07-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168664842},
#  {'date': '2022-07-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168611017},
#  {'date': '2022-07-03',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168573131},
#  {'date': '2022-07-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168543584},
#  {'date': '2022-07-01',
#   'NewCasesByPublishDate': 20731,
#   'PCRTestsByPublishDate': 168502597},
#  {'date': '2022-06-30',
#   'NewCasesByPublishDate': 21732,
#   'PCRTestsByPublishDate': 168457837},
#  {'date': '2022-06-29',
#   'NewCasesByPublishDate': 21428,
#   'PCRTestsByPublishDate': 168382382},
#  {'date': '2022-06-28',
#   'NewCasesByPublishDate': 21415,
#   'PCRTestsByPublishDate': 168328712},
#  {'date': '2022-06-27',
#   'NewCasesByPublishDate': 47332,
#   'PCRTestsByPublishDate': 168276071},
#  {'date': '2022-06-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168236466},
#  {'date': '2022-06-25',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 168203609},
#  {'date': '2022-06-24',
#   'NewCasesByPublishDate': 16489,
#   'PCRTestsByPublishDate': 168164188},
#  {'date': '2022-06-23',
#   'NewCasesByPublishDate': 17481,
#   'PCRTestsByPublishDate': 168121391},
#  {'date': '2022-06-22',
#   'NewCasesByPublishDate': 17202,
#   'PCRTestsByPublishDate': 168044996},
#  {'date': '2022-06-21',
#   'NewCasesByPublishDate': 16432,
#   'PCRTestsByPublishDate': 168004216},
#  {'date': '2022-06-20',
#   'NewCasesByPublishDate': 36452,
#   'PCRTestsByPublishDate': 167952703},
#  {'date': '2022-06-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167912441},
#  {'date': '2022-06-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167880693},
#  {'date': '2022-06-17',
#   'NewCasesByPublishDate': 12065,
#   'PCRTestsByPublishDate': 167845897},
#  {'date': '2022-06-16',
#   'NewCasesByPublishDate': 12080,
#   'PCRTestsByPublishDate': 167803818},
#  {'date': '2022-06-15',
#   'NewCasesByPublishDate': 13401,
#   'PCRTestsByPublishDate': 167723876},
#  {'date': '2022-06-14',
#   'NewCasesByPublishDate': 12031,
#   'PCRTestsByPublishDate': 167678730},
#  {'date': '2022-06-13',
#   'NewCasesByPublishDate': 28249,
#   'PCRTestsByPublishDate': 167632760},
#  {'date': '2022-06-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167591166},
#  {'date': '2022-06-11',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167560009},
#  {'date': '2022-06-10',
#   'NewCasesByPublishDate': 9217,
#   'PCRTestsByPublishDate': 167524629},
#  {'date': '2022-06-09',
#   'NewCasesByPublishDate': 9741,
#   'PCRTestsByPublishDate': 167485044},
#  {'date': '2022-06-08',
#   'NewCasesByPublishDate': 9298,
#   'PCRTestsByPublishDate': 167420441},
#  {'date': '2022-06-07',
#   'NewCasesByPublishDate': 10240,
#   'PCRTestsByPublishDate': 167360093},
#  {'date': '2022-06-06',
#   'NewCasesByPublishDate': 29155,
#   'PCRTestsByPublishDate': 167281613},
#  {'date': '2022-06-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167238653},
#  {'date': '2022-06-04',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167206332},
#  {'date': '2022-06-03',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167172123},
#  {'date': '2022-06-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 167139596},
#  {'date': '2022-06-01',
#   'NewCasesByPublishDate': 5313,
#   'PCRTestsByPublishDate': 167103392},
#  {'date': '2022-05-31',
#   'NewCasesByPublishDate': 5802,
#   'PCRTestsByPublishDate': 167056718},
#  {'date': '2022-05-30',
#   'NewCasesByPublishDate': 13590,
#   'PCRTestsByPublishDate': 167013220},
#  {'date': '2022-05-29',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166970611},
#  {'date': '2022-05-28',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166936315},
#  {'date': '2022-05-27',
#   'NewCasesByPublishDate': 4661,
#   'PCRTestsByPublishDate': 166898758},
#  {'date': '2022-05-26',
#   'NewCasesByPublishDate': 5293,
#   'PCRTestsByPublishDate': 166854428},
#  {'date': '2022-05-25',
#   'NewCasesByPublishDate': 5810,
#   'PCRTestsByPublishDate': 166782092},
#  {'date': '2022-05-24',
#   'NewCasesByPublishDate': 6352,
#   'PCRTestsByPublishDate': 166731036},
#  {'date': '2022-05-23',
#   'NewCasesByPublishDate': 14592,
#   'PCRTestsByPublishDate': 166676723},
#  {'date': '2022-05-22',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166627746},
#  {'date': '2022-05-21',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166588330},
#  {'date': '2022-05-20',
#   'NewCasesByPublishDate': 6003,
#   'PCRTestsByPublishDate': 166544724},
#  {'date': '2022-05-19',
#   'NewCasesByPublishDate': 6704,
#   'PCRTestsByPublishDate': 166494692},
#  {'date': '2022-05-18',
#   'NewCasesByPublishDate': 7388,
#   'PCRTestsByPublishDate': 166422355},
#  {'date': '2022-05-17',
#   'NewCasesByPublishDate': 8102,
#   'PCRTestsByPublishDate': 166365575},
#  {'date': '2022-05-16',
#   'NewCasesByPublishDate': 16903,
#   'PCRTestsByPublishDate': 166309189},
#  {'date': '2022-05-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166257190},
#  {'date': '2022-05-14',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 166218068},
#  {'date': '2022-05-13',
#   'NewCasesByPublishDate': 6511,
#   'PCRTestsByPublishDate': 166171203},
#  {'date': '2022-05-12',
#   'NewCasesByPublishDate': 10874,
#   'PCRTestsByPublishDate': 166116109},
#  {'date': '2022-05-11',
#   'NewCasesByPublishDate': 8036,
#   'PCRTestsByPublishDate': 166043903},
#  {'date': '2022-05-10',
#   'NewCasesByPublishDate': 9751,
#   'PCRTestsByPublishDate': 165985202},
#  {'date': '2022-05-09',
#   'NewCasesByPublishDate': 21712,
#   'PCRTestsByPublishDate': 165897008},
#  {'date': '2022-05-08',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 165841602},
#  {'date': '2022-05-07',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 165794264},
#  {'date': '2022-05-06',
#   'NewCasesByPublishDate': 9405,
#   'PCRTestsByPublishDate': 165739259},
#  {'date': '2022-05-05',
#   'NewCasesByPublishDate': 10311,
#   'PCRTestsByPublishDate': 165675652},
#  {'date': '2022-05-04',
#   'NewCasesByPublishDate': 14596,
#   'PCRTestsByPublishDate': 165596987},
#  {'date': '2022-05-03',
#   'NewCasesByPublishDate': 29029,
#   'PCRTestsByPublishDate': 165520001},
#  {'date': '2022-05-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 165457182},
#  {'date': '2022-05-01',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 165409755},
#  {'date': '2022-04-30',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 165362004},
#  {'date': '2022-04-29',
#   'NewCasesByPublishDate': 9705,
#   'PCRTestsByPublishDate': 165305821},
#  {'date': '2022-04-28',
#   'NewCasesByPublishDate': 10945,
#   'PCRTestsByPublishDate': 165243127},
#  {'date': '2022-04-27',
#   'NewCasesByPublishDate': 13481,
#   'PCRTestsByPublishDate': 165151996},
#  {'date': '2022-04-26',
#   'NewCasesByPublishDate': 13045,
#   'PCRTestsByPublishDate': 165076164},
#  {'date': '2022-04-25',
#   'NewCasesByPublishDate': 35925,
#   'PCRTestsByPublishDate': 164986639},
#  {'date': '2022-04-24',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164923689},
#  {'date': '2022-04-23',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164873578},
#  {'date': '2022-04-22',
#   'NewCasesByPublishDate': 15832,
#   'PCRTestsByPublishDate': 164807598},
#  {'date': '2022-04-21',
#   'NewCasesByPublishDate': 18475,
#   'PCRTestsByPublishDate': 164738159},
#  {'date': '2022-04-20',
#   'NewCasesByPublishDate': 20767,
#   'PCRTestsByPublishDate': 164634885},
#  {'date': '2022-04-19',
#   'NewCasesByPublishDate': 93281,
#   'PCRTestsByPublishDate': 164546886},
#  {'date': '2022-04-18',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164470284},
#  {'date': '2022-04-17',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164390756},
#  {'date': '2022-04-16',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164334503},
#  {'date': '2022-04-15',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 164276745},
#  {'date': '2022-04-14',
#   'NewCasesByPublishDate': 27283,
#   'PCRTestsByPublishDate': 164213119},
#  {'date': '2022-04-13',
#   'NewCasesByPublishDate': 29335,
#   'PCRTestsByPublishDate': 164136826},
#  {'date': '2022-04-12',
#   'NewCasesByPublishDate': 31230,
#   'PCRTestsByPublishDate': 164045731},
#  {'date': '2022-04-11',
#   'NewCasesByPublishDate': 75194,
#   'PCRTestsByPublishDate': 163958023},
#  {'date': '2022-04-10',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 163883022},
#  {'date': '2022-04-09',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 163818883},
#  {'date': '2022-04-08',
#   'NewCasesByPublishDate': 33782,
#   'PCRTestsByPublishDate': 163735198},
#  {'date': '2022-04-07',
#   'NewCasesByPublishDate': 38678,
#   'PCRTestsByPublishDate': 163648097},
#  {'date': '2022-04-06',
#   'NewCasesByPublishDate': 42392,
#   'PCRTestsByPublishDate': 163540619},
#  {'date': '2022-04-05',
#   'NewCasesByPublishDate': 41436,
#   'PCRTestsByPublishDate': 163400022},
#  {'date': '2022-04-04',
#   'NewCasesByPublishDate': 122027,
#   'PCRTestsByPublishDate': 163276342},
#  {'date': '2022-04-03',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 163197012},
#  {'date': '2022-04-02',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 163089199},
#  {'date': '2022-04-01',
#   'NewCasesByPublishDate': 60220,
#   'PCRTestsByPublishDate': 162991924},
#  {'date': '2022-03-31',
#   'NewCasesByPublishDate': 62816,
#   'PCRTestsByPublishDate': 162841340},
#  {'date': '2022-03-30',
#   'NewCasesByPublishDate': 74419,
#   'PCRTestsByPublishDate': 162661406},
#  {'date': '2022-03-29',
#   'NewCasesByPublishDate': 64935,
#   'PCRTestsByPublishDate': 162486558},
#  {'date': '2022-03-28',
#   'NewCasesByPublishDate': 183459,
#   'PCRTestsByPublishDate': 162284234},
#  {'date': '2022-03-27',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 162163226},
#  {'date': '2022-03-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 162041324},
#  {'date': '2022-03-25',
#   'NewCasesByPublishDate': 63371,
#   'PCRTestsByPublishDate': 161905494},
#  {'date': '2022-03-24',
#   'NewCasesByPublishDate': 79373,
#   'PCRTestsByPublishDate': 161749431},
#  {'date': '2022-03-23',
#   'NewCasesByPublishDate': 85916,
#   'PCRTestsByPublishDate': 161541906},
#  {'date': '2022-03-22',
#   'NewCasesByPublishDate': 74804,
#   'PCRTestsByPublishDate': 161354237},
#  {'date': '2022-03-21',
#   'NewCasesByPublishDate': 188925,
#   'PCRTestsByPublishDate': 161152014},
#  {'date': '2022-03-20',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 161033001},
#  {'date': '2022-03-19',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 160923396},
#  {'date': '2022-03-18',
#   'NewCasesByPublishDate': 68492,
#   'PCRTestsByPublishDate': 160774702},
#  {'date': '2022-03-17',
#   'NewCasesByPublishDate': 75681,
#   'PCRTestsByPublishDate': 160612253},
#  {'date': '2022-03-16',
#   'NewCasesByPublishDate': 76366,
#   'PCRTestsByPublishDate': 160396137},
#  {'date': '2022-03-15',
#   'NewCasesByPublishDate': 64313,
#   'PCRTestsByPublishDate': 160214901},
#  {'date': '2022-03-14',
#   'NewCasesByPublishDate': 163954,
#   'PCRTestsByPublishDate': 160007266},
#  {'date': '2022-03-13',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 159906161},
#  {'date': '2022-03-12',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 159801979},
#  {'date': '2022-03-11',
#   'NewCasesByPublishDate': 55883,
#   'PCRTestsByPublishDate': 159672199},
#  {'date': '2022-03-10',
#   'NewCasesByPublishDate': 52722,
#   'PCRTestsByPublishDate': 159528559},
#  {'date': '2022-03-09',
#   'NewCasesByPublishDate': 51378,
#   'PCRTestsByPublishDate': 159354130},
#  {'date': '2022-03-08',
#   'NewCasesByPublishDate': 44918,
#   'PCRTestsByPublishDate': 159201449},
#  {'date': '2022-03-07',
#   'NewCasesByPublishDate': 95324,
#   'PCRTestsByPublishDate': 159036003},
#  {'date': '2022-03-06',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 158930564},
#  {'date': '2022-03-05',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 158836289},
#  {'date': '2022-03-04',
#   'NewCasesByPublishDate': 31776,
#   'PCRTestsByPublishDate': 158712156},
#  {'date': '2022-03-03',
#   'NewCasesByPublishDate': 32858,
#   'PCRTestsByPublishDate': 158580806},
#  {'date': '2022-03-02',
#   'NewCasesByPublishDate': 32077,
#   'PCRTestsByPublishDate': 158357581},
#  {'date': '2022-03-01',
#   'NewCasesByPublishDate': 26711,
#   'PCRTestsByPublishDate': 158221522},
#  {'date': '2022-02-28',
#   'NewCasesByPublishDate': 60595,
#   'PCRTestsByPublishDate': 158082537},
#  {'date': '2022-02-27',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 157996961},
#  {'date': '2022-02-26',
#   'NewCasesByPublishDate': 0,
#   'PCRTestsByPublishDate': 157921525},
#  {'date': '2022-02-25',
#   'NewCasesByPublishDate': 23526,
#   'PCRTestsByPublishDate': 157814262},
#  {'date': '2022-02-24',
#   'NewCasesByPublishDate': 28193,
#   'PCRTestsByPublishDate': 157696202},
#  {'date': '2022-02-23',
#   'NewCasesByPublishDate': 29703,
#   'PCRTestsByPublishDate': 157511433},
#  {'date': '2022-02-22',
#   'NewCasesByPublishDate': 30080,
#   'PCRTestsByPublishDate': 157373021},
#  {'date': '2022-02-21',
#   'NewCasesByPublishDate': 29753,
#   'PCRTestsByPublishDate': 157216282},
#  {'date': '2022-02-20',
#   'NewCasesByPublishDate': 23831,
#   'PCRTestsByPublishDate': 157112582},
#  {'date': '2022-02-19',
#   'NewCasesByPublishDate': 32230,
#   'PCRTestsByPublishDate': 157004591},
#  {'date': '2022-02-18',
#   'NewCasesByPublishDate': 36900,
#   'PCRTestsByPublishDate': 156889372},
#  {'date': '2022-02-17',
#   'NewCasesByPublishDate': 40376,
#   'PCRTestsByPublishDate': 156739563},
#  {'date': '2022-02-16',
#   'NewCasesByPublishDate': 42756,
#   'PCRTestsByPublishDate': 156528215},
#  {'date': '2022-02-15',
#   'NewCasesByPublishDate': 36471,
#   'PCRTestsByPublishDate': 156335198},
#  {'date': '2022-02-14',
#   'NewCasesByPublishDate': 31943,
#   'PCRTestsByPublishDate': 156111821},
#  {'date': '2022-02-13',
#   'NewCasesByPublishDate': 32316,
#   'PCRTestsByPublishDate': 155990063},
#  {'date': '2022-02-12',
#   'NewCasesByPublishDate': 37791,
#   'PCRTestsByPublishDate': 155873173},
#  {'date': '2022-02-11',
#   'NewCasesByPublishDate': 46736,
#   'PCRTestsByPublishDate': 155684681},
#  {'date': '2022-02-10',
#   'NewCasesByPublishDate': 53993,
#   'PCRTestsByPublishDate': 155468829},
#  {'date': '2022-02-09',
#   'NewCasesByPublishDate': 59193,
#   'PCRTestsByPublishDate': 155225604},
#  {'date': '2022-02-08',
#   'NewCasesByPublishDate': 58453,
#   'PCRTestsByPublishDate': 154982567},
#  {'date': '2022-02-07',
#   'NewCasesByPublishDate': 48601,
#   'PCRTestsByPublishDate': 154703886},
#  {'date': '2022-02-06',
#   'NewCasesByPublishDate': 49533,
#   'PCRTestsByPublishDate': 154553937},
#  {'date': '2022-02-05',
#   'NewCasesByPublishDate': 57377,
#   'PCRTestsByPublishDate': 154408058},
#  {'date': '2022-02-04',
#   'NewCasesByPublishDate': 73185,
#   'PCRTestsByPublishDate': 154176891},
#  {'date': '2022-02-03',
#   'NewCasesByPublishDate': 77189,
#   'PCRTestsByPublishDate': 153920776},
#  {'date': '2022-02-02',
#   'NewCasesByPublishDate': 81446,
#   'PCRTestsByPublishDate': 153598357},
#  {'date': '2022-02-01',
#   'NewCasesByPublishDate': 103353,
#   'PCRTestsByPublishDate': 153306529},
#  {'date': '2022-01-31',
#   'NewCasesByPublishDate': 81720,
#   'PCRTestsByPublishDate': 153007290},
#  {'date': '2022-01-30',
#   'NewCasesByPublishDate': 59559,
#   'PCRTestsByPublishDate': 152830212},
#  {'date': '2022-01-29',
#   'NewCasesByPublishDate': 69137,
#   'PCRTestsByPublishDate': 152653689},
#  {'date': '2022-01-28',
#   'NewCasesByPublishDate': 78711,
#   'PCRTestsByPublishDate': 152402668},
#  {'date': '2022-01-27',
#   'NewCasesByPublishDate': 85288,
#   'PCRTestsByPublishDate': 152121304},
#  {'date': '2022-01-26',
#   'NewCasesByPublishDate': 90587,
#   'PCRTestsByPublishDate': 151796763},
#  {'date': '2022-01-25',
#   'NewCasesByPublishDate': 84302,
#   'PCRTestsByPublishDate': 151480448},
#  {'date': '2022-01-24',
#   'NewCasesByPublishDate': 77232,
#   'PCRTestsByPublishDate': 151146495},
#  {'date': '2022-01-23',
#   'NewCasesByPublishDate': 68913,
#   'PCRTestsByPublishDate': 150964865},
#  {'date': '2022-01-22',
#   'NewCasesByPublishDate': 73331,
#   'PCRTestsByPublishDate': 150778788},
#  {'date': '2022-01-21',
#   'NewCasesByPublishDate': 85902,
#   'PCRTestsByPublishDate': 150517935},
#  {'date': '2022-01-20',
#   'NewCasesByPublishDate': 95974,
#   'PCRTestsByPublishDate': 150222364},
#  {'date': '2022-01-19',
#   'NewCasesByPublishDate': 96545,
#   'PCRTestsByPublishDate': 149865583},
#  {'date': '2022-01-18',
#   'NewCasesByPublishDate': 84987,
#   'PCRTestsByPublishDate': 149516534},
#  {'date': '2022-01-17',
#   'NewCasesByPublishDate': 74249,
#   'PCRTestsByPublishDate': 149168819},
#  {'date': '2022-01-16',
#   'NewCasesByPublishDate': 66273,
#   'PCRTestsByPublishDate': 148989455},
#  {'date': '2022-01-15',
#   'NewCasesByPublishDate': 74576,
#   'PCRTestsByPublishDate': 148790032},
#  {'date': '2022-01-14',
#   'NewCasesByPublishDate': 87857,
#   'PCRTestsByPublishDate': 148498045},
#  {'date': '2022-01-13',
#   'NewCasesByPublishDate': 97770,
#   'PCRTestsByPublishDate': 148181797},
#  {'date': '2022-01-12',
#   'NewCasesByPublishDate': 116173,
#   'PCRTestsByPublishDate': 147797172},
#  {'date': '2022-01-11',
#   'NewCasesByPublishDate': 104833,
#   'PCRTestsByPublishDate': 147384117},
#  {'date': '2022-01-10',
#   'NewCasesByPublishDate': 115998,
#   'PCRTestsByPublishDate': 146935010},
#  {'date': '2022-01-09',
#   'NewCasesByPublishDate': 121228,
#   'PCRTestsByPublishDate': 146543038},
#  {'date': '2022-01-08',
#   'NewCasesByPublishDate': 130330,
#   'PCRTestsByPublishDate': 146079822},
#  {'date': '2022-01-07',
#   'NewCasesByPublishDate': 149405,
#   'PCRTestsByPublishDate': 145566953},
#  {'date': '2022-01-06',
#   'NewCasesByPublishDate': 152306,
#   'PCRTestsByPublishDate': 145010739},
#  {'date': '2022-01-05',
#   'NewCasesByPublishDate': 150232,
#   'PCRTestsByPublishDate': 144410147},
#  {'date': '2022-01-04',
#   'NewCasesByPublishDate': 148725,
#   'PCRTestsByPublishDate': 143905796},
#  {'date': '2022-01-03',
#   'NewCasesByPublishDate': 137541,
#   'PCRTestsByPublishDate': 143394313},
#  {'date': '2022-01-02',
#   'NewCasesByPublishDate': 123547,
#   'PCRTestsByPublishDate': 142953875},
#  {'date': '2022-01-01',
#   'NewCasesByPublishDate': 162572,
#   'PCRTestsByPublishDate': 142525549},
#  {'date': '2021-12-31',
#   'NewCasesByPublishDate': 160276,
#   'PCRTestsByPublishDate': 142149540},
#  {'date': '2021-12-30',
#   'NewCasesByPublishDate': 146604,
#   'PCRTestsByPublishDate': 141707617},
#  {'date': '2021-12-29',
#   'NewCasesByPublishDate': 138287,
#   'PCRTestsByPublishDate': 141231430},
#  {'date': '2021-12-28',
#   'NewCasesByPublishDate': 117093,
#   'PCRTestsByPublishDate': 140859977},
#  {'date': '2021-12-27',
#   'NewCasesByPublishDate': 98515,
#   'PCRTestsByPublishDate': 140480931},
#  {'date': '2021-12-26',
#   'NewCasesByPublishDate': 103558,
#   'PCRTestsByPublishDate': 140114282},
#  {'date': '2021-12-25',
#   'NewCasesByPublishDate': 113628,
#   'PCRTestsByPublishDate': 139736598},
#  {'date': '2021-12-24',
#   'NewCasesByPublishDate': 105069,
#   'PCRTestsByPublishDate': 139331950},
#  {'date': '2021-12-23',
#   'NewCasesByPublishDate': 107055,
#   'PCRTestsByPublishDate': 138846491},
#  {'date': '2021-12-22',
#   'NewCasesByPublishDate': 95795,
#   'PCRTestsByPublishDate': 138306060},
#  {'date': '2021-12-21',
#   'NewCasesByPublishDate': 80916,
#   'PCRTestsByPublishDate': 137829581},
#  {'date': '2021-12-20',
#   'NewCasesByPublishDate': 76065,
#   'PCRTestsByPublishDate': 137367896},
#  {'date': '2021-12-19',
#   'NewCasesByPublishDate': 71702,
#   'PCRTestsByPublishDate': 136965023},
#  {'date': '2021-12-18',
#   'NewCasesByPublishDate': 82426,
#   'PCRTestsByPublishDate': 136509283},
#  {'date': '2021-12-17',
#   'NewCasesByPublishDate': 83693,
#   'PCRTestsByPublishDate': 136080879},
#  {'date': '2021-12-16',
#   'NewCasesByPublishDate': 77299,
#   'PCRTestsByPublishDate': 135589921},
#  {'date': '2021-12-15',
#   'NewCasesByPublishDate': 68868,
#   'PCRTestsByPublishDate': 135092570},
#  {'date': '2021-12-14',
#   'NewCasesByPublishDate': 53093,
#   'PCRTestsByPublishDate': 134601217},
#  {'date': '2021-12-13',
#   'NewCasesByPublishDate': 44931,
#   'PCRTestsByPublishDate': 134161992},
#  {'date': '2021-12-12',
#   'NewCasesByPublishDate': 40713,
#   'PCRTestsByPublishDate': 133829589},
#  {'date': '2021-12-11',
#   'NewCasesByPublishDate': 48540,
#   'PCRTestsByPublishDate': 133485947},
#  {'date': '2021-12-10',
#   'NewCasesByPublishDate': 48908,
#   'PCRTestsByPublishDate': 133151702},
#  {'date': '2021-12-09',
#   'NewCasesByPublishDate': 43550,
#   'PCRTestsByPublishDate': 132717951},
#  {'date': '2021-12-08',
#   'NewCasesByPublishDate': 44019,
#   'PCRTestsByPublishDate': 132248883},
#  {'date': '2021-12-07',
#   'NewCasesByPublishDate': 38866,
#   'PCRTestsByPublishDate': 131827072},
#  {'date': '2021-12-06',
#   'NewCasesByPublishDate': 41525,
#   'PCRTestsByPublishDate': 131439669},
#  {'date': '2021-12-05',
#   'NewCasesByPublishDate': 37396,
#   'PCRTestsByPublishDate': 131151082},
#  {'date': '2021-12-04',
#   'NewCasesByPublishDate': 39949,
#   'PCRTestsByPublishDate': 130792528},
#  {'date': '2021-12-03',
#   'NewCasesByPublishDate': 43888,
#   'PCRTestsByPublishDate': 130415568},
#  {'date': '2021-12-02',
#   'NewCasesByPublishDate': 45880,
#   'PCRTestsByPublishDate': 129991932},
#  {'date': '2021-12-01',
#   'NewCasesByPublishDate': 41519,
#   'PCRTestsByPublishDate': 129559778},
#  {'date': '2021-11-30',
#   'NewCasesByPublishDate': 33590,
#   'PCRTestsByPublishDate': 129172291},
#  {'date': '2021-11-29',
#   'NewCasesByPublishDate': 34906,
#   'PCRTestsByPublishDate': 128793893},
#  {'date': '2021-11-28',
#   'NewCasesByPublishDate': 32136,
#   'PCRTestsByPublishDate': 128557101},
#  {'date': '2021-11-27',
#   'NewCasesByPublishDate': 35798,
#   'PCRTestsByPublishDate': 128285766},
#  {'date': '2021-11-26',
#   'NewCasesByPublishDate': 42272,
#   'PCRTestsByPublishDate': 127950574},
#  {'date': '2021-11-25',
#   'NewCasesByPublishDate': 40382,
#   'PCRTestsByPublishDate': 127601837},
#  {'date': '2021-11-24',
#   'NewCasesByPublishDate': 36511,
#   'PCRTestsByPublishDate': 127177619},
#  {'date': '2021-11-23',
#   'NewCasesByPublishDate': 36550,
#   'PCRTestsByPublishDate': 126809642},
#  {'date': '2021-11-22',
#   'NewCasesByPublishDate': 36478,
#   'PCRTestsByPublishDate': 126421140},
#  {'date': '2021-11-21',
#   'NewCasesByPublishDate': 33513,
#   'PCRTestsByPublishDate': 126139572},
#  {'date': '2021-11-20',
#   'NewCasesByPublishDate': 36339,
#   'PCRTestsByPublishDate': 125757310},
#  {'date': '2021-11-19',
#   'NewCasesByPublishDate': 37006,
#   'PCRTestsByPublishDate': 125415433},
#  {'date': '2021-11-18',
#   'NewCasesByPublishDate': 39315,
#   'PCRTestsByPublishDate': 125069892},
#  {'date': '2021-11-17',
#   'NewCasesByPublishDate': 30638,
#   'PCRTestsByPublishDate': 124715400},
#  {'date': '2021-11-16',
#   'NewCasesByPublishDate': 30853,
#   'PCRTestsByPublishDate': 124298601},
#  {'date': '2021-11-15',
#   'NewCasesByPublishDate': 31440,
#   'PCRTestsByPublishDate': 124016668},
#  {'date': '2021-11-14',
#   'NewCasesByPublishDate': 29404,
#   'PCRTestsByPublishDate': 123791464},
#  {'date': '2021-11-13',
#   'NewCasesByPublishDate': 33493,
#   'PCRTestsByPublishDate': 123542580},
#  {'date': '2021-11-12',
#   'NewCasesByPublishDate': 33155,
#   'PCRTestsByPublishDate': 123241789},
#  {'date': '2021-11-11',
#   'NewCasesByPublishDate': 35472,
#   'PCRTestsByPublishDate': 122931273},
#  {'date': '2021-11-10',
#   'NewCasesByPublishDate': 31541,
#   'PCRTestsByPublishDate': 122562736},
#  {'date': '2021-11-09',
#   'NewCasesByPublishDate': 27872,
#   'PCRTestsByPublishDate': 122222215},
#  {'date': '2021-11-08',
#   'NewCasesByPublishDate': 24979,
#   'PCRTestsByPublishDate': 121894199},
#  {'date': '2021-11-07',
#   'NewCasesByPublishDate': 23779,
#   'PCRTestsByPublishDate': 121661313},
#  {'date': '2021-11-06',
#   'NewCasesByPublishDate': 26250,
#   'PCRTestsByPublishDate': 121472645},
#  {'date': '2021-11-05',
#   'NewCasesByPublishDate': 28490,
#   'PCRTestsByPublishDate': 121182433},
#  {'date': '2021-11-04',
#   'NewCasesByPublishDate': 30166,
#   'PCRTestsByPublishDate': 120850298},
#  {'date': '2021-11-03',
#   'NewCasesByPublishDate': 34317,
#   'PCRTestsByPublishDate': 120529610},
#  {'date': '2021-11-02',
#   'NewCasesByPublishDate': 28531,
#   'PCRTestsByPublishDate': 120221532},
#  {'date': '2021-11-01',
#   'NewCasesByPublishDate': 32081,
#   'PCRTestsByPublishDate': 119887577},
#  {'date': '2021-10-31',
#   'NewCasesByPublishDate': 31479,
#   'PCRTestsByPublishDate': 119691972},
#  {'date': '2021-10-30',
#   'NewCasesByPublishDate': 36204,
#   'PCRTestsByPublishDate': 119483533},
#  {'date': '2021-10-29',
#   'NewCasesByPublishDate': 36853,
#   'PCRTestsByPublishDate': 119192439},
#  {'date': '2021-10-28',
#   'NewCasesByPublishDate': 33903,
#   'PCRTestsByPublishDate': 118869181},
#  {'date': '2021-10-27',
#   'NewCasesByPublishDate': 37502,
#   'PCRTestsByPublishDate': 118512605},
#  {'date': '2021-10-26',
#   'NewCasesByPublishDate': 32280,
#   'PCRTestsByPublishDate': 118183549},
#  {'date': '2021-10-25',
#   'NewCasesByPublishDate': 33309,
#   'PCRTestsByPublishDate': 117857329},
#  {'date': '2021-10-24',
#   'NewCasesByPublishDate': 33221,
#   'PCRTestsByPublishDate': 117638230},
#  {'date': '2021-10-23',
#   'NewCasesByPublishDate': 41259,
#   'PCRTestsByPublishDate': 117344026},
#  {'date': '2021-10-22',
#   'NewCasesByPublishDate': 41745,
#   'PCRTestsByPublishDate': 117020248},
#  {'date': '2021-10-21',
#   'NewCasesByPublishDate': 44363,
#   'PCRTestsByPublishDate': 116641686},
#  {'date': '2021-10-20',
#   'NewCasesByPublishDate': 41498,
#   'PCRTestsByPublishDate': 116230613},
#  {'date': '2021-10-19',
#   'NewCasesByPublishDate': 36712,
#   'PCRTestsByPublishDate': 115844168},
#  {'date': '2021-10-18',
#   'NewCasesByPublishDate': 39473,
#   'PCRTestsByPublishDate': 115492067},
#  {'date': '2021-10-17',
#   'NewCasesByPublishDate': 38543,
#   'PCRTestsByPublishDate': 115270000},
#  {'date': '2021-10-16',
#   'NewCasesByPublishDate': 39624,
#   'PCRTestsByPublishDate': 114990463},
#  {'date': '2021-10-15',
#   'NewCasesByPublishDate': 37691,
#   'PCRTestsByPublishDate': 114613510},
#  {'date': '2021-10-14',
#   'NewCasesByPublishDate': 38488,
#   'PCRTestsByPublishDate': 114208883},
#  {'date': '2021-10-13',
#   'NewCasesByPublishDate': 36458,
#   'PCRTestsByPublishDate': 113827075},
#  {'date': '2021-10-12',
#   'NewCasesByPublishDate': 33287,
#   'PCRTestsByPublishDate': 113474078},
#  {'date': '2021-10-11',
#   'NewCasesByPublishDate': 32349,
#   'PCRTestsByPublishDate': 113113978},
#  {'date': '2021-10-10',
#   'NewCasesByPublishDate': 31096,
#   'PCRTestsByPublishDate': 112871645},
#  {'date': '2021-10-09',
#   'NewCasesByPublishDate': 31259,
#   'PCRTestsByPublishDate': 112617549},
#  {'date': '2021-10-08',
#   'NewCasesByPublishDate': 32157,
#   'PCRTestsByPublishDate': 112268673},
#  {'date': '2021-10-07',
#   'NewCasesByPublishDate': 33305,
#   'PCRTestsByPublishDate': 111878458},
#  {'date': '2021-10-06',
#   'NewCasesByPublishDate': 33450,
#   'PCRTestsByPublishDate': 111492904},
#  {'date': '2021-10-05',
#   'NewCasesByPublishDate': 28846,
#   'PCRTestsByPublishDate': 111135386},
#  {'date': '2021-10-04',
#   'NewCasesByPublishDate': 28251,
#   'PCRTestsByPublishDate': 110787686},
#  {'date': '2021-10-03',
#   'NewCasesByPublishDate': 25176,
#   'PCRTestsByPublishDate': 110540996},
#  {'date': '2021-10-02',
#   'NewCasesByPublishDate': 26794,
#   'PCRTestsByPublishDate': 110277570},
#  {'date': '2021-10-01',
#   'NewCasesByPublishDate': 28836,
#   'PCRTestsByPublishDate': 109962082},
#  {'date': '2021-09-30',
#   'NewCasesByPublishDate': 29826,
#   'PCRTestsByPublishDate': 109599080},
#  {'date': '2021-09-29',
#   'NewCasesByPublishDate': 29036,
#   'PCRTestsByPublishDate': 109183644},
#  {'date': '2021-09-28',
#   'NewCasesByPublishDate': 28808,
#   'PCRTestsByPublishDate': 108824317},
#  {'date': '2021-09-27',
#   'NewCasesByPublishDate': 29329,
#   'PCRTestsByPublishDate': 108493423},
#  {'date': '2021-09-26',
#   'NewCasesByPublishDate': 25538,
#   'PCRTestsByPublishDate': 108230613},
#  {'date': '2021-09-25',
#   'NewCasesByPublishDate': 28087,
#   'PCRTestsByPublishDate': 107926328},
#  {'date': '2021-09-24',
#   'NewCasesByPublishDate': 28199,
#   'PCRTestsByPublishDate': 107607723},
#  {'date': '2021-09-23',
#   'NewCasesByPublishDate': 29045,
#   'PCRTestsByPublishDate': 107250514},
#  {'date': '2021-09-22',
#   'NewCasesByPublishDate': 27317,
#   'PCRTestsByPublishDate': 106843596},
#  {'date': '2021-09-21',
#   'NewCasesByPublishDate': 24973,
#   'PCRTestsByPublishDate': 106553453},
#  {'date': '2021-09-20',
#   'NewCasesByPublishDate': 26905,
#   'PCRTestsByPublishDate': 106221723},
#  {'date': '2021-09-19',
#   'NewCasesByPublishDate': 22173,
#   'PCRTestsByPublishDate': 105967491},
#  {'date': '2021-09-18',
#   'NewCasesByPublishDate': 22956,
#   'PCRTestsByPublishDate': 105719283},
#  {'date': '2021-09-17',
#   'NewCasesByPublishDate': 23265,
#   'PCRTestsByPublishDate': 105443798},
#  {'date': '2021-09-16',
#   'NewCasesByPublishDate': 22949,
#   'PCRTestsByPublishDate': 105142393},
#  {'date': '2021-09-15',
#   'NewCasesByPublishDate': 22078,
#   'PCRTestsByPublishDate': 104792952},
#  {'date': '2021-09-14',
#   'NewCasesByPublishDate': 19739,
#   'PCRTestsByPublishDate': 104465704},
#  {'date': '2021-09-13',
#   'NewCasesByPublishDate': 21077,
#   'PCRTestsByPublishDate': 104171292},
#  {'date': '2021-09-12',
#   'NewCasesByPublishDate': 19913,
#   'PCRTestsByPublishDate': 103961017},
#  {'date': '2021-09-11',
#   'NewCasesByPublishDate': 23825,
#   'PCRTestsByPublishDate': 103738187},
#  {'date': '2021-09-10',
#   'NewCasesByPublishDate': 26653,
#   'PCRTestsByPublishDate': 103429074},
#  {'date': '2021-09-09',
#   'NewCasesByPublishDate': 27049,
#   'PCRTestsByPublishDate': 103137771},
#  {'date': '2021-09-08',
#   'NewCasesByPublishDate': 29286,
#   'PCRTestsByPublishDate': 102811121},
#  {'date': '2021-09-07',
#   'NewCasesByPublishDate': 27545,
#   'PCRTestsByPublishDate': 102501600},
#  {'date': '2021-09-06',
#   'NewCasesByPublishDate': 27202,
#   'PCRTestsByPublishDate': 102230305},
#  {'date': '2021-09-05',
#   'NewCasesByPublishDate': 27022,
#   'PCRTestsByPublishDate': 102009649},
#  {'date': '2021-09-04',
#   'NewCasesByPublishDate': 29614,
#   'PCRTestsByPublishDate': 101757999},
#  {'date': '2021-09-03',
#   'NewCasesByPublishDate': 31726,
#   'PCRTestsByPublishDate': 101465954},
#  {'date': '2021-09-02',
#   'NewCasesByPublishDate': 28686,
#   'PCRTestsByPublishDate': 101159966},
#  {'date': '2021-09-01',
#   'NewCasesByPublishDate': 24723,
#   'PCRTestsByPublishDate': 100794605},
#  {'date': '2021-08-31',
#   'NewCasesByPublishDate': 20967,
#   'PCRTestsByPublishDate': 100526980},
#  {'date': '2021-08-30',
#   'NewCasesByPublishDate': 21324,
#   'PCRTestsByPublishDate': 100313985},
#  {'date': '2021-08-29',
#   'NewCasesByPublishDate': 22501,
#   'PCRTestsByPublishDate': 100164483},
#  {'date': '2021-08-28',
#   'NewCasesByPublishDate': 25118,
#   'PCRTestsByPublishDate': 99958289},
#  {'date': '2021-08-27',
#   'NewCasesByPublishDate': 27545,
#   'PCRTestsByPublishDate': 99725470},
#  {'date': '2021-08-26',
#   'NewCasesByPublishDate': 29417,
#   'PCRTestsByPublishDate': 99448568},
#  {'date': '2021-08-25',
#   'NewCasesByPublishDate': 27350,
#   'PCRTestsByPublishDate': 99117271},
#  {'date': '2021-08-24',
#   'NewCasesByPublishDate': 23474,
#   'PCRTestsByPublishDate': 98806066},
#  {'date': '2021-08-23',
#   'NewCasesByPublishDate': 24158,
#   'PCRTestsByPublishDate': 98544852},
#  {'date': '2021-08-22',
#   'NewCasesByPublishDate': 25952,
#   'PCRTestsByPublishDate': 98366367},
#  {'date': '2021-08-21',
#   'NewCasesByPublishDate': 26982,
#   'PCRTestsByPublishDate': 98156794},
#  {'date': '2021-08-20',
#   'NewCasesByPublishDate': 29576,
#   'PCRTestsByPublishDate': 97878796},
#  {'date': '2021-08-19',
#   'NewCasesByPublishDate': 29762,
#   'PCRTestsByPublishDate': 97598051},
#  {'date': '2021-08-18',
#   'NewCasesByPublishDate': 28648,
#   'PCRTestsByPublishDate': 97278171},
#  {'date': '2021-08-17',
#   'NewCasesByPublishDate': 22712,
#   'PCRTestsByPublishDate': 96963100},
#  {'date': '2021-08-16',
#   'NewCasesByPublishDate': 23171,
#   'PCRTestsByPublishDate': 96677684},
#  {'date': '2021-08-15',
#   'NewCasesByPublishDate': 22859,
#   'PCRTestsByPublishDate': 96516382},
#  {'date': '2021-08-14',
#   'NewCasesByPublishDate': 26700,
#   'PCRTestsByPublishDate': 96311800},
#  {'date': '2021-08-13',
#   'NewCasesByPublishDate': 28679,
#   'PCRTestsByPublishDate': 96056347},
#  {'date': '2021-08-12',
#   'NewCasesByPublishDate': 28093,
#   'PCRTestsByPublishDate': 95758395},
#  {'date': '2021-08-11',
#   'NewCasesByPublishDate': 26647,
#   'PCRTestsByPublishDate': 95440285},
#  {'date': '2021-08-10',
#   'NewCasesByPublishDate': 20630,
#   'PCRTestsByPublishDate': 95145441},
#  {'date': '2021-08-09',
#   'NewCasesByPublishDate': 21915,
#   'PCRTestsByPublishDate': 94871034},
#  {'date': '2021-08-08',
#   'NewCasesByPublishDate': 24196,
#   'PCRTestsByPublishDate': 94702252},
#  {'date': '2021-08-07',
#   'NewCasesByPublishDate': 25877,
#   'PCRTestsByPublishDate': 94494248},
#  {'date': '2021-08-06',
#   'NewCasesByPublishDate': 28321,
#   'PCRTestsByPublishDate': 94215794},
#  {'date': '2021-08-05',
#   'NewCasesByPublishDate': 26512,
#   'PCRTestsByPublishDate': 93939503},
#  {'date': '2021-08-04',
#   'NewCasesByPublishDate': 26393,
#   'PCRTestsByPublishDate': 93649888},
#  {'date': '2021-08-03',
#   'NewCasesByPublishDate': 19012,
#   'PCRTestsByPublishDate': 93340395},
#  {'date': '2021-08-02',
#   'NewCasesByPublishDate': 19175,
#   'PCRTestsByPublishDate': 93049058},
#  {'date': '2021-08-01',
#   'NewCasesByPublishDate': 21645,
#   'PCRTestsByPublishDate': 92891789},
#  {'date': '2021-07-31',
#   'NewCasesByPublishDate': 23949,
#   'PCRTestsByPublishDate': 92714155},
#  {'date': '2021-07-30',
#   'NewCasesByPublishDate': 26241,
#   'PCRTestsByPublishDate': 92425406},
#  {'date': '2021-07-29',
#   'NewCasesByPublishDate': 27524,
#   'PCRTestsByPublishDate': 92120969},
#  {'date': '2021-07-28',
#   'NewCasesByPublishDate': 24367,
#   'PCRTestsByPublishDate': 91799346},
#  {'date': '2021-07-27',
#   'NewCasesByPublishDate': 20290,
#   'PCRTestsByPublishDate': 91472894},
#  {'date': '2021-07-26',
#   'NewCasesByPublishDate': 22181,
#   'PCRTestsByPublishDate': 91166112},
#  {'date': '2021-07-25',
#   'NewCasesByPublishDate': 25434,
#   'PCRTestsByPublishDate': 90975054},
#  {'date': '2021-07-24',
#   'NewCasesByPublishDate': 28968,
#   'PCRTestsByPublishDate': 90752091},
#  {'date': '2021-07-23',
#   'NewCasesByPublishDate': 32792,
#   'PCRTestsByPublishDate': 90442167},
#  {'date': '2021-07-22',
#   'NewCasesByPublishDate': 35939,
#   'PCRTestsByPublishDate': 90103151},
#  {'date': '2021-07-21',
#   'NewCasesByPublishDate': 39504,
#   'PCRTestsByPublishDate': 89705501},
#  {'date': '2021-07-20',
#   'NewCasesByPublishDate': 43261,
#   'PCRTestsByPublishDate': 89360192},
#  {'date': '2021-07-19',
#   'NewCasesByPublishDate': 34657,
#   'PCRTestsByPublishDate': 89023622},
#  {'date': '2021-07-18',
#   'NewCasesByPublishDate': 44777,
#   'PCRTestsByPublishDate': 88661709},
#  {'date': '2021-07-17',
# ...
#  {'date': '2020-08-30',
#   'NewCasesByPublishDate': 1487,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-29',
#   'NewCasesByPublishDate': 891,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-28',
#   'NewCasesByPublishDate': 1106,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-27',
#   'NewCasesByPublishDate': 1350,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-26',
#   'NewCasesByPublishDate': 875,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-25',
#   'NewCasesByPublishDate': 1065,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-24',
#   'NewCasesByPublishDate': 758,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-23',
#   'NewCasesByPublishDate': 938,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-22',
#   'NewCasesByPublishDate': 1060,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-21',
#   'NewCasesByPublishDate': 908,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-20',
#   'NewCasesByPublishDate': 1035,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-19',
#   'NewCasesByPublishDate': 707,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-18',
#   'NewCasesByPublishDate': 975,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-17',
#   'NewCasesByPublishDate': 634,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-16',
#   'NewCasesByPublishDate': 952,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-15',
#   'NewCasesByPublishDate': 934,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-14',
#   'NewCasesByPublishDate': 1284,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-13',
#   'NewCasesByPublishDate': 1059,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-12',
#   'NewCasesByPublishDate': 925,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-11',
#   'NewCasesByPublishDate': 1035,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-10',
#   'NewCasesByPublishDate': 699,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-09',
#   'NewCasesByPublishDate': 988,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-08',
#   'NewCasesByPublishDate': 679,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-07',
#   'NewCasesByPublishDate': 796,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-06',
#   'NewCasesByPublishDate': 826,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-05',
#   'NewCasesByPublishDate': 804,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-04',
#   'NewCasesByPublishDate': 617,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-03',
#   'NewCasesByPublishDate': 856,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-02',
#   'NewCasesByPublishDate': 676,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-08-01',
#   'NewCasesByPublishDate': 722,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-31',
#   'NewCasesByPublishDate': 814,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-30',
#   'NewCasesByPublishDate': 812,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-29',
#   'NewCasesByPublishDate': 700,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-28',
#   'NewCasesByPublishDate': 547,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-27',
#   'NewCasesByPublishDate': 616,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-26',
#   'NewCasesByPublishDate': 721,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-25',
#   'NewCasesByPublishDate': 710,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-24',
#   'NewCasesByPublishDate': 688,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-23',
#   'NewCasesByPublishDate': 702,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-22',
#   'NewCasesByPublishDate': 519,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-21',
#   'NewCasesByPublishDate': 399,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-20',
#   'NewCasesByPublishDate': 535,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-19',
#   'NewCasesByPublishDate': 672,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-18',
#   'NewCasesByPublishDate': 796,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-17',
#   'NewCasesByPublishDate': 635,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-16',
#   'NewCasesByPublishDate': 597,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-15',
#   'NewCasesByPublishDate': 506,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-14',
#   'NewCasesByPublishDate': 372,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-13',
#   'NewCasesByPublishDate': 497,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-12',
#   'NewCasesByPublishDate': 615,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-11',
#   'NewCasesByPublishDate': 806,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-10',
#   'NewCasesByPublishDate': 480,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-09',
#   'NewCasesByPublishDate': 617,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-08',
#   'NewCasesByPublishDate': 606,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-07',
#   'NewCasesByPublishDate': 572,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-06',
#   'NewCasesByPublishDate': 331,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-05',
#   'NewCasesByPublishDate': 492,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-04',
#   'NewCasesByPublishDate': 579,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-03',
#   'NewCasesByPublishDate': 502,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-02',
#   'NewCasesByPublishDate': 523,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-07-01',
#   'NewCasesByPublishDate': 177,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-30',
#   'NewCasesByPublishDate': 196,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-29',
#   'NewCasesByPublishDate': 99,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-28',
#   'NewCasesByPublishDate': 142,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-27',
#   'NewCasesByPublishDate': 192,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-26',
#   'NewCasesByPublishDate': 175,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-25',
#   'NewCasesByPublishDate': 261,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-24',
#   'NewCasesByPublishDate': 107,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-23',
#   'NewCasesByPublishDate': 210,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-22',
#   'NewCasesByPublishDate': 178,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-21',
#   'NewCasesByPublishDate': 215,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-20',
#   'NewCasesByPublishDate': 324,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-19',
#   'NewCasesByPublishDate': 323,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-18',
#   'NewCasesByPublishDate': 281,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-17',
#   'NewCasesByPublishDate': 252,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-16',
#   'NewCasesByPublishDate': 252,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-15',
#   'NewCasesByPublishDate': 219,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-14',
#   'NewCasesByPublishDate': 292,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-13',
#   'NewCasesByPublishDate': 372,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-12',
#   'NewCasesByPublishDate': 392,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-11',
#   'NewCasesByPublishDate': 304,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-10',
#   'NewCasesByPublishDate': 63,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-09',
#   'NewCasesByPublishDate': 651,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-08',
#   'NewCasesByPublishDate': 92,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-07',
#   'NewCasesByPublishDate': 228,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-06',
#   'NewCasesByPublishDate': 422,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-05',
#   'NewCasesByPublishDate': 451,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-04',
#   'NewCasesByPublishDate': 431,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-03',
#   'NewCasesByPublishDate': 462,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-02',
#   'NewCasesByPublishDate': 444,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-06-01',
#   'NewCasesByPublishDate': 294,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-31',
#   'NewCasesByPublishDate': 320,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-30',
#   'NewCasesByPublishDate': 715,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-29',
#   'NewCasesByPublishDate': 560,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-28',
#   'NewCasesByPublishDate': 519,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-27',
#   'NewCasesByPublishDate': 609,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-26',
#   'NewCasesByPublishDate': 492,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-25',
#   'NewCasesByPublishDate': 494,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-24',
#   'NewCasesByPublishDate': 584,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-23',
#   'NewCasesByPublishDate': 979,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-22',
#   'NewCasesByPublishDate': 1083,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-21',
#   'NewCasesByPublishDate': 854,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-20',
#   'NewCasesByPublishDate': 824,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-19',
#   'NewCasesByPublishDate': 857,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-18',
#   'NewCasesByPublishDate': 816,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-17',
#   'NewCasesByPublishDate': 788,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-16',
#   'NewCasesByPublishDate': 1136,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-15',
#   'NewCasesByPublishDate': 1112,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-14',
#   'NewCasesByPublishDate': 1189,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-13',
#   'NewCasesByPublishDate': 1146,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-12',
#   'NewCasesByPublishDate': 1067,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-11',
#   'NewCasesByPublishDate': 891,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-10',
#   'NewCasesByPublishDate': 1007,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-09',
#   'NewCasesByPublishDate': 1349,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-08',
#   'NewCasesByPublishDate': 1694,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-07',
#   'NewCasesByPublishDate': 2133,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-06',
#   'NewCasesByPublishDate': 1611,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-05',
#   'NewCasesByPublishDate': 1842,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-04',
#   'NewCasesByPublishDate': 1485,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-03',
#   'NewCasesByPublishDate': 2019,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-02',
#   'NewCasesByPublishDate': 2228,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-05-01',
#   'NewCasesByPublishDate': 2501,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-30',
#   'NewCasesByPublishDate': 2484,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-29',
#   'NewCasesByPublishDate': 1403,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-28',
#   'NewCasesByPublishDate': 1989,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-27',
#   'NewCasesByPublishDate': 2264,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-26',
#   'NewCasesByPublishDate': 2152,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-25',
#   'NewCasesByPublishDate': 2826,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-24',
#   'NewCasesByPublishDate': 3004,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-23',
#   'NewCasesByPublishDate': 3084,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-22',
#   'NewCasesByPublishDate': 3020,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-21',
#   'NewCasesByPublishDate': 3087,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-20',
#   'NewCasesByPublishDate': 2401,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-19',
#   'NewCasesByPublishDate': 3607,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-18',
#   'NewCasesByPublishDate': 3548,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-17',
#   'NewCasesByPublishDate': 3985,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-16',
#   'NewCasesByPublishDate': 3118,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-15',
#   'NewCasesByPublishDate': 3188,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-14',
#   'NewCasesByPublishDate': 3854,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-13',
#   'NewCasesByPublishDate': 2999,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-12',
#   'NewCasesByPublishDate': 3672,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-11',
#   'NewCasesByPublishDate': 3841,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-10',
#   'NewCasesByPublishDate': 4263,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-09',
#   'NewCasesByPublishDate': 3798,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-08',
#   'NewCasesByPublishDate': 4788,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-07',
#   'NewCasesByPublishDate': 2978,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-06',
#   'NewCasesByPublishDate': 3176,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-05',
#   'NewCasesByPublishDate': 5107,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-04',
#   'NewCasesByPublishDate': 2910,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-03',
#   'NewCasesByPublishDate': 3576,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-02',
#   'NewCasesByPublishDate': 3583,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-04-01',
#   'NewCasesByPublishDate': 3630,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-31',
#   'NewCasesByPublishDate': 2414,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-30',
#   'NewCasesByPublishDate': 2107,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-29',
#   'NewCasesByPublishDate': 2060,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-28',
#   'NewCasesByPublishDate': 2139,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-27',
#   'NewCasesByPublishDate': 2506,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-26',
#   'NewCasesByPublishDate': 1809,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-25',
#   'NewCasesByPublishDate': 1130,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-24',
#   'NewCasesByPublishDate': 1258,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-23',
#   'NewCasesByPublishDate': 793,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-22',
#   'NewCasesByPublishDate': 535,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-21',
#   'NewCasesByPublishDate': 873,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-20',
#   'NewCasesByPublishDate': 628,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-19',
#   'NewCasesByPublishDate': 574,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-18',
#   'NewCasesByPublishDate': 625,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-17',
#   'NewCasesByPublishDate': 361,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-16',
#   'NewCasesByPublishDate': 97,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-15',
#   'NewCasesByPublishDate': 253,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-14',
#   'NewCasesByPublishDate': 201,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-13',
#   'NewCasesByPublishDate': 159,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-12',
#   'NewCasesByPublishDate': 99,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-11',
#   'NewCasesByPublishDate': 63,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-10',
#   'NewCasesByPublishDate': 46,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-09',
#   'NewCasesByPublishDate': 40,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-08',
#   'NewCasesByPublishDate': 58,
#   'PCRTestsByPublishDate': None},
#  {'date': '2020-03-07',
#   'NewCasesByPublishDate': 39,
#   'PCRTestsByPublishDate': None},
#  ...]

# %% [markdown]
# ## Wrangle the data
#
# The logic to wrangle the raw data into a ```DataFrame``` that will be used for plotting is listed below.

# %%
dates = [dictionary['date'] for dictionary in data_list]
dates.sort()
dates
# Out:
# ['2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
#  '2020-02-28',
#  '2020-02-29',
#  '2020-03-01',
#  '2020-03-02',
#  '2020-03-03',
#  '2020-03-04',
#  '2020-03-05',
#  '2020-03-06',
#  '2020-03-07',
#  '2020-03-08',
#  '2020-03-09',
#  '2020-03-10',
#  '2020-03-11',
#  '2020-03-12',
#  '2020-03-13',
#  '2020-03-14',
#  '2020-03-15',
#  '2020-03-16',
#  '2020-03-17',
#  '2020-03-18',
#  '2020-03-19',
#  '2020-03-20',
#  '2020-03-21',
#  '2020-03-22',
#  '2020-03-23',
#  '2020-03-24',
#  '2020-03-25',
#  '2020-03-26',
#  '2020-03-27',
#  '2020-03-28',
#  '2020-03-29',
#  '2020-03-30',
#  '2020-03-31',
#  '2020-04-01',
#  '2020-04-02',
#  '2020-04-03',
#  '2020-04-04',
#  '2020-04-05',
#  '2020-04-06',
#  '2020-04-07',
#  '2020-04-08',
#  '2020-04-09',
#  '2020-04-10',
#  '2020-04-11',
#  '2020-04-12',
#  '2020-04-13',
#  '2020-04-14',
#  '2020-04-15',
#  '2020-04-16',
#  '2020-04-17',
#  '2020-04-18',
#  '2020-04-19',
#  '2020-04-20',
#  '2020-04-21',
#  '2020-04-22',
#  '2020-04-23',
#  '2020-04-24',
#  '2020-04-25',
#  '2020-04-26',
#  '2020-04-27',
#  '2020-04-28',
#  '2020-04-29',
#  '2020-04-30',
#  '2020-05-01',
#  '2020-05-02',
#  '2020-05-03',
#  '2020-05-04',
#  '2020-05-05',
#  '2020-05-06',
#  '2020-05-07',
#  '2020-05-08',
#  '2020-05-09',
#  '2020-05-10',
#  '2020-05-11',
#  '2020-05-12',
#  '2020-05-13',
#  '2020-05-14',
#  '2020-05-15',
#  '2020-05-16',
#  '2020-05-17',
#  '2020-05-18',
#  '2020-05-19',
#  '2020-05-20',
#  '2020-05-21',
#  '2020-05-22',
#  '2020-05-23',
#  '2020-05-24',
#  '2020-05-25',
#  '2020-05-26',
#  '2020-05-27',
#  '2020-05-28',
#  '2020-05-29',
#  '2020-05-30',
#  '2020-05-31',
#  '2020-06-01',
#  '2020-06-02',
#  '2020-06-03',
#  '2020-06-04',
#  '2020-06-05',
#  '2020-06-06',
#  '2020-06-07',
#  '2020-06-08',
#  '2020-06-09',
#  '2020-06-10',
#  '2020-06-11',
#  '2020-06-12',
#  '2020-06-13',
#  '2020-06-14',
#  '2020-06-15',
#  '2020-06-16',
#  '2020-06-17',
#  '2020-06-18',
#  '2020-06-19',
#  '2020-06-20',
#  '2020-06-21',
#  '2020-06-22',
#  '2020-06-23',
#  '2020-06-24',
#  '2020-06-25',
#  '2020-06-26',
#  '2020-06-27',
#  '2020-06-28',
#  '2020-06-29',
#  '2020-06-30',
#  '2020-07-01',
#  '2020-07-02',
#  '2020-07-03',
#  '2020-07-04',
#  '2020-07-05',
#  '2020-07-06',
#  '2020-07-07',
#  '2020-07-08',
#  '2020-07-09',
#  '2020-07-10',
#  '2020-07-11',
#  '2020-07-12',
#  '2020-07-13',
#  '2020-07-14',
#  '2020-07-15',
#  '2020-07-16',
#  '2020-07-17',
#  '2020-07-18',
#  '2020-07-19',
#  '2020-07-20',
#  '2020-07-21',
#  '2020-07-22',
#  '2020-07-23',
#  '2020-07-24',
#  '2020-07-25',
#  '2020-07-26',
#  '2020-07-27',
#  '2020-07-28',
#  '2020-07-29',
#  '2020-07-30',
#  '2020-07-31',
#  '2020-08-01',
#  '2020-08-02',
#  '2020-08-03',
#  '2020-08-04',
#  '2020-08-05',
#  '2020-08-06',
#  '2020-08-07',
#  '2020-08-08',
#  '2020-08-09',
#  '2020-08-10',
#  '2020-08-11',
#  '2020-08-12',
#  '2020-08-13',
#  '2020-08-14',
#  '2020-08-15',
#  '2020-08-16',
#  '2020-08-17',
#  '2020-08-18',
#  '2020-08-19',
#  '2020-08-20',
#  '2020-08-21',
#  '2020-08-22',
#  '2020-08-23',
#  '2020-08-24',
#  '2020-08-25',
#  '2020-08-26',
#  '2020-08-27',
#  '2020-08-28',
#  '2020-08-29',
#  '2020-08-30',
#  '2020-08-31',
#  '2020-09-01',
#  '2020-09-02',
#  '2020-09-03',
#  '2020-09-04',
#  '2020-09-05',
#  '2020-09-06',
#  '2020-09-07',
#  '2020-09-08',
#  '2020-09-09',
#  '2020-09-10',
#  '2020-09-11',
#  '2020-09-12',
#  '2020-09-13',
#  '2020-09-14',
#  '2020-09-15',
#  '2020-09-16',
#  '2020-09-17',
#  '2020-09-18',
#  '2020-09-19',
#  '2020-09-20',
#  '2020-09-21',
#  '2020-09-22',
#  '2020-09-23',
#  '2020-09-24',
#  '2020-09-25',
#  '2020-09-26',
#  '2020-09-27',
#  '2020-09-28',
#  '2020-09-29',
#  '2020-09-30',
#  '2020-10-01',
#  '2020-10-02',
#  '2020-10-03',
#  '2020-10-04',
#  '2020-10-05',
#  '2020-10-06',
#  '2020-10-07',
#  '2020-10-08',
#  '2020-10-09',
#  '2020-10-10',
#  '2020-10-11',
#  '2020-10-12',
#  '2020-10-13',
#  '2020-10-14',
#  '2020-10-15',
#  '2020-10-16',
#  '2020-10-17',
#  '2020-10-18',
#  '2020-10-19',
#  '2020-10-20',
#  '2020-10-21',
#  '2020-10-22',
#  '2020-10-23',
#  '2020-10-24',
#  '2020-10-25',
#  '2020-10-26',
#  '2020-10-27',
#  '2020-10-28',
#  '2020-10-29',
#  '2020-10-30',
#  '2020-10-31',
#  '2020-11-01',
#  '2020-11-02',
#  '2020-11-03',
#  '2020-11-04',
#  '2020-11-05',
#  '2020-11-06',
#  '2020-11-07',
#  '2020-11-08',
#  '2020-11-09',
#  '2020-11-10',
#  '2020-11-11',
#  '2020-11-12',
#  '2020-11-13',
#  '2020-11-14',
#  '2020-11-15',
#  '2020-11-16',
#  '2020-11-17',
#  '2020-11-18',
#  '2020-11-19',
#  '2020-11-20',
#  '2020-11-21',
#  '2020-11-22',
#  '2020-11-23',
#  '2020-11-24',
#  '2020-11-25',
#  '2020-11-26',
#  '2020-11-27',
#  '2020-11-28',
#  '2020-11-29',
#  '2020-11-30',
#  '2020-12-01',
#  '2020-12-02',
#  '2020-12-03',
#  '2020-12-04',
#  '2020-12-05',
#  '2020-12-06',
#  '2020-12-07',
#  '2020-12-08',
#  '2020-12-09',
#  '2020-12-10',
#  '2020-12-11',
#  '2020-12-12',
#  '2020-12-13',
#  '2020-12-14',
#  '2020-12-15',
#  '2020-12-16',
#  '2020-12-17',
#  '2020-12-18',
#  '2020-12-19',
#  '2020-12-20',
#  '2020-12-21',
#  '2020-12-22',
#  '2020-12-23',
#  '2020-12-24',
#  '2020-12-25',
#  '2020-12-26',
#  '2020-12-27',
#  '2020-12-28',
#  '2020-12-29',
#  '2020-12-30',
#  '2020-12-31',
#  '2021-01-01',
#  '2021-01-02',
#  '2021-01-03',
#  '2021-01-04',
#  '2021-01-05',
#  '2021-01-06',
#  '2021-01-07',
#  '2021-01-08',
#  '2021-01-09',
#  '2021-01-10',
#  '2021-01-11',
#  '2021-01-12',
#  '2021-01-13',
#  '2021-01-14',
#  '2021-01-15',
#  '2021-01-16',
#  '2021-01-17',
#  '2021-01-18',
#  '2021-01-19',
#  '2021-01-20',
#  '2021-01-21',
#  '2021-01-22',
#  '2021-01-23',
#  '2021-01-24',
#  '2021-01-25',
#  '2021-01-26',
#  '2021-01-27',
#  '2021-01-28',
#  '2021-01-29',
#  '2021-01-30',
#  '2021-01-31',
#  '2021-02-01',
#  '2021-02-02',
#  '2021-02-03',
#  '2021-02-04',
#  '2021-02-05',
#  '2021-02-06',
#  '2021-02-07',
#  '2021-02-08',
#  '2021-02-09',
#  '2021-02-10',
#  '2021-02-11',
#  '2021-02-12',
#  '2021-02-13',
#  '2021-02-14',
#  '2021-02-15',
#  '2021-02-16',
#  '2021-02-17',
#  '2021-02-18',
#  '2021-02-19',
#  '2021-02-20',
#  '2021-02-21',
#  '2021-02-22',
#  '2021-02-23',
#  '2021-02-24',
#  '2021-02-25',
#  '2021-02-26',
#  '2021-02-27',
#  '2021-02-28',
#  '2021-03-01',
#  '2021-03-02',
#  '2021-03-03',
#  '2021-03-04',
#  '2021-03-05',
#  '2021-03-06',
#  '2021-03-07',
#  '2021-03-08',
#  '2021-03-09',
#  '2021-03-10',
#  '2021-03-11',
#  '2021-03-12',
#  '2021-03-13',
#  '2021-03-14',
#  '2021-03-15',
#  '2021-03-16',
#  '2021-03-17',
#  '2021-03-18',
#  '2021-03-19',
#  '2021-03-20',
#  '2021-03-21',
#  '2021-03-22',
#  '2021-03-23',
#  '2021-03-24',
#  '2021-03-25',
#  '2021-03-26',
#  '2021-03-27',
#  '2021-03-28',
#  '2021-03-29',
#  '2021-03-30',
#  '2021-03-31',
#  '2021-04-01',
#  '2021-04-02',
#  '2021-04-03',
#  '2021-04-04',
#  '2021-04-05',
#  '2021-04-06',
#  '2021-04-07',
#  '2021-04-08',
#  '2021-04-09',
#  '2021-04-10',
#  '2021-04-11',
#  '2021-04-12',
#  '2021-04-13',
#  '2021-04-14',
#  '2021-04-15',
#  '2021-04-16',
#  '2021-04-17',
#  '2021-04-18',
#  '2021-04-19',
#  '2021-04-20',
#  '2021-04-21',
#  '2021-04-22',
#  '2021-04-23',
#  '2021-04-24',
#  '2021-04-25',
#  '2021-04-26',
#  '2021-04-27',
#  '2021-04-28',
#  '2021-04-29',
#  '2021-04-30',
#  '2021-05-01',
#  '2021-05-02',
#  '2021-05-03',
#  '2021-05-04',
#  '2021-05-05',
#  '2021-05-06',
#  '2021-05-07',
#  '2021-05-08',
#  '2021-05-09',
#  '2021-05-10',
#  '2021-05-11',
#  '2021-05-12',
#  '2021-05-13',
#  '2021-05-14',
#  '2021-05-15',
#  '2021-05-16',
#  '2021-05-17',
#  '2021-05-18',
#  '2021-05-19',
#  '2021-05-20',
#  '2021-05-21',
#  '2021-05-22',
#  '2021-05-23',
#  '2021-05-24',
#  '2021-05-25',
#  '2021-05-26',
#  '2021-05-27',
#  '2021-05-28',
#  '2021-05-29',
#  '2021-05-30',
#  '2021-05-31',
#  '2021-06-01',
#  '2021-06-02',
#  '2021-06-03',
#  '2021-06-04',
#  '2021-06-05',
#  '2021-06-06',
#  '2021-06-07',
#  '2021-06-08',
#  '2021-06-09',
#  '2021-06-10',
#  '2021-06-11',
#  '2021-06-12',
#  '2021-06-13',
#  '2021-06-14',
#  '2021-06-15',
#  '2021-06-16',
#  '2021-06-17',
#  '2021-06-18',
#  '2021-06-19',
#  '2021-06-20',
#  '2021-06-21',
#  '2021-06-22',
#  '2021-06-23',
#  '2021-06-24',
#  '2021-06-25',
#  '2021-06-26',
#  '2021-06-27',
#  '2021-06-28',
#  '2021-06-29',
#  '2021-06-30',
#  '2021-07-01',
#  '2021-07-02',
#  '2021-07-03',
#  '2021-07-04',
#  '2021-07-05',
#  '2021-07-06',
#  '2021-07-07',
#  '2021-07-08',
#  '2021-07-09',
#  '2021-07-10',
#  '2021-07-11',
#  '2021-07-12',
#  '2021-07-13',
#  '2021-07-14',
#  '2021-07-15',
#  '2021-07-16',
#  '2021-07-17',
#  '2021-07-18',
#  '2021-07-19',
#  '2021-07-20',
#  '2021-07-21',
#  '2021-07-22',
#  '2021-07-23',
#  '2021-07-24',
#  '2021-07-25',
#  '2021-07-26',
#  '2021-07-27',
#  '2021-07-28',
#  '2021-07-29',
#  '2021-07-30',
#  '2021-07-31',
#  '2021-08-01',
#  '2021-08-02',
#  '2021-08-03',
#  '2021-08-04',
#  '2021-08-05',
#  '2021-08-06',
#  '2021-08-07',
#  '2021-08-08',
#  '2021-08-09',
#  '2021-08-10',
#  '2021-08-11',
#  '2021-08-12',
#  '2021-08-13',
#  '2021-08-14',
#  '2021-08-15',
#  '2021-08-16',
#  '2021-08-17',
#  '2021-08-18',
#  '2021-08-19',
#  '2021-08-20',
#  '2021-08-21',
#  '2021-08-22',
#  '2021-08-23',
#  '2021-08-24',
#  '2021-08-25',
#  '2021-08-26',
#  '2021-08-27',
#  '2021-08-28',
#  '2021-08-29',
#  '2021-08-30',
#  '2021-08-31',
#  '2021-09-01',
#  '2021-09-02',
#  '2021-09-03',
#  '2021-09-04',
#  '2021-09-05',
#  '2021-09-06',
#  '2021-09-07',
#  '2021-09-08',
#  '2021-09-09',
#  '2021-09-10',
#  '2021-09-11',
#  '2021-09-12',
#  '2021-09-13',
#  '2021-09-14',
#  '2021-09-15',
#  '2021-09-16',
#  '2021-09-17',
#  '2021-09-18',
#  '2021-09-19',
#  '2021-09-20',
#  '2021-09-21',
#  '2021-09-22',
#  '2021-09-23',
#  '2021-09-24',
#  '2021-09-25',
#  '2021-09-26',
#  '2021-09-27',
#  '2021-09-28',
#  '2021-09-29',
#  '2021-09-30',
#  '2021-10-01',
#  '2021-10-02',
#  '2021-10-03',
#  '2021-10-04',
#  '2021-10-05',
#  '2021-10-06',
#  '2021-10-07',
#  '2021-10-08',
#  '2021-10-09',
#  '2021-10-10',
#  '2021-10-11',
#  '2021-10-12',
#  '2021-10-13',
#  '2021-10-14',
#  '2021-10-15',
#  '2021-10-16',
#  '2021-10-17',
#  '2021-10-18',
#  '2021-10-19',
#  '2021-10-20',
#  '2021-10-21',
#  '2021-10-22',
#  '2021-10-23',
#  '2021-10-24',
#  '2021-10-25',
#  '2021-10-26',
#  '2021-10-27',
#  '2021-10-28',
#  '2021-10-29',
#  '2021-10-30',
#  '2021-10-31',
#  '2021-11-01',
#  '2021-11-02',
#  '2021-11-03',
#  '2021-11-04',
#  '2021-11-05',
#  '2021-11-06',
#  '2021-11-07',
#  '2021-11-08',
#  '2021-11-09',
#  '2021-11-10',
#  '2021-11-11',
#  '2021-11-12',
#  '2021-11-13',
#  '2021-11-14',
#  '2021-11-15',
#  '2021-11-16',
#  '2021-11-17',
#  '2021-11-18',
#  '2021-11-19',
#  '2021-11-20',
#  '2021-11-21',
#  '2021-11-22',
#  '2021-11-23',
#  '2021-11-24',
#  '2021-11-25',
#  '2021-11-26',
#  '2021-11-27',
#  '2021-11-28',
#  '2021-11-29',
#  '2021-11-30',
#  '2021-12-01',
#  '2021-12-02',
#  '2021-12-03',
#  '2021-12-04',
#  '2021-12-05',
#  '2021-12-06',
#  '2021-12-07',
#  '2021-12-08',
#  '2021-12-09',
#  '2021-12-10',
#  '2021-12-11',
#  '2021-12-12',
#  '2021-12-13',
#  '2021-12-14',
#  '2021-12-15',
#  '2021-12-16',
#  '2021-12-17',
#  '2021-12-18',
#  '2021-12-19',
#  '2021-12-20',
#  '2021-12-21',
#  '2021-12-22',
#  '2021-12-23',
#  '2021-12-24',
#  '2021-12-25',
#  '2021-12-26',
#  '2021-12-27',
#  '2021-12-28',
#  '2021-12-29',
#  '2021-12-30',
#  '2021-12-31',
#  '2022-01-01',
#  '2022-01-02',
#  '2022-01-03',
#  '2022-01-04',
#  '2022-01-05',
#  '2022-01-06',
#  '2022-01-07',
#  '2022-01-08',
#  '2022-01-09',
#  '2022-01-10',
#  '2022-01-11',
#  '2022-01-12',
#  '2022-01-13',
#  '2022-01-14',
#  '2022-01-15',
#  '2022-01-16',
#  '2022-01-17',
#  '2022-01-18',
#  '2022-01-19',
#  '2022-01-20',
#  '2022-01-21',
#  '2022-01-22',
#  '2022-01-23',
#  '2022-01-24',
#  '2022-01-25',
#  '2022-01-26',
#  '2022-01-27',
#  '2022-01-28',
#  '2022-01-29',
#  '2022-01-30',
#  '2022-01-31',
#  '2022-02-01',
#  '2022-02-02',
#  '2022-02-03',
#  '2022-02-04',
#  '2022-02-05',
#  '2022-02-06',
#  '2022-02-07',
#  '2022-02-08',
#  '2022-02-09',
#  '2022-02-10',
#  '2022-02-11',
#  '2022-02-12',
#  '2022-02-13',
#  '2022-02-14',
#  '2022-02-15',
#  '2022-02-16',
#  '2022-02-17',
#  '2022-02-18',
#  '2022-02-19',
#  '2022-02-20',
#  '2022-02-21',
#  '2022-02-22',
#  '2022-02-23',
#  '2022-02-24',
#  '2022-02-25',
#  '2022-02-26',
#  '2022-02-27',
#  '2022-02-28',
#  '2022-03-01',
#  '2022-03-02',
#  '2022-03-03',
#  '2022-03-04',
#  '2022-03-05',
#  '2022-03-06',
#  '2022-03-07',
#  '2022-03-08',
#  '2022-03-09',
#  '2022-03-10',
#  '2022-03-11',
#  '2022-03-12',
#  '2022-03-13',
#  '2022-03-14',
#  '2022-03-15',
#  '2022-03-16',
#  '2022-03-17',
#  '2022-03-18',
#  '2022-03-19',
#  '2022-03-20',
#  '2022-03-21',
#  '2022-03-22',
#  '2022-03-23',
#  '2022-03-24',
#  '2022-03-25',
#  '2022-03-26',
#  '2022-03-27',
#  '2022-03-28',
#  '2022-03-29',
#  '2022-03-30',
#  '2022-03-31',
#  '2022-04-01',
#  '2022-04-02',
#  '2022-04-03',
#  '2022-04-04',
#  '2022-04-05',
#  '2022-04-06',
#  '2022-04-07',
#  '2022-04-08',
#  '2022-04-09',
#  '2022-04-10',
#  '2022-04-11',
#  '2022-04-12',
#  '2022-04-13',
#  '2022-04-14',
#  '2022-04-15',
#  '2022-04-16',
#  '2022-04-17',
#  '2022-04-18',
#  '2022-04-19',
#  '2022-04-20',
#  '2022-04-21',
#  '2022-04-22',
#  '2022-04-23',
#  '2022-04-24',
#  '2022-04-25',
#  '2022-04-26',
#  '2022-04-27',
#  '2022-04-28',
#  '2022-04-29',
#  '2022-04-30',
#  '2022-05-01',
#  '2022-05-02',
#  '2022-05-03',
#  '2022-05-04',
#  '2022-05-05',
#  '2022-05-06',
#  '2022-05-07',
#  '2022-05-08',
#  '2022-05-09',
#  '2022-05-10',
#  '2022-05-11',
#  '2022-05-12',
#  '2022-05-13',
#  '2022-05-14',
#  '2022-05-15',
#  '2022-05-16',
#  '2022-05-17',
#  '2022-05-18',
#  '2022-05-19',
#  '2022-05-20',
#  '2022-05-21',
#  '2022-05-22',
#  '2022-05-23',
#  '2022-05-24',
#  '2022-05-25',
#  '2022-05-26',
#  '2022-05-27',
#  '2022-05-28',
#  '2022-05-29',
#  '2022-05-30',
#  '2022-05-31',
#  '2022-06-01',
#  '2022-06-02',
#  '2022-06-03',
#  '2022-06-04',
#  '2022-06-05',
#  '2022-06-06',
#  '2022-06-07',
#  '2022-06-08',
#  '2022-06-09',
#  '2022-06-10',
#  '2022-06-11',
#  '2022-06-12',
#  '2022-06-13',
#  '2022-06-14',
#  '2022-06-15',
#  '2022-06-16',
#  '2022-06-17',
#  '2022-06-18',
#  '2022-06-19',
#  '2022-06-20',
#  '2022-06-21',
#  '2022-06-22',
#  '2022-06-23',
#  '2022-06-24',
#  '2022-06-25',
#  '2022-06-26',
#  '2022-06-27',
#  '2022-06-28',
#  '2022-06-29',
#  '2022-06-30',
#  '2022-07-01',
#  '2022-07-02',
#  '2022-07-03',
#  '2022-07-04',
#  '2022-07-05',
#  '2022-07-06',
#  '2022-07-07',
#  '2022-07-08',
#  '2022-07-09',
#  '2022-07-10',
#  '2022-07-11',
#  '2022-07-12',
#  '2022-07-13',
#  '2022-07-14',
#  '2022-07-15',
#  '2022-07-16',
#  '2022-07-17',
#  '2022-07-18',
#  '2022-07-19',
#  '2022-07-20',
#  '2022-07-21',
#  '2022-07-22',
#  '2022-07-23',
#  '2022-07-24',
#  '2022-07-25',
#  '2022-07-26',
#  '2022-07-27',
#  '2022-07-28',
#  '2022-07-29',
#  '2022-07-30',
#  '2022-07-31',
#  '2022-08-01',
#  '2022-08-02',
#  '2022-08-03',
#  '2022-08-04',
#  '2022-08-05',
#  '2022-08-06',
#  '2022-08-07',
#  '2022-08-08',
#  '2022-08-09',
#  '2022-08-10',
#  '2022-08-11',
#  '2022-08-12',
#  '2022-08-13',
#  '2022-08-14',
#  '2022-08-15',
#  '2022-08-16',
#  '2022-08-17',
#  '2022-08-18',
#  '2022-08-19',
#  '2022-08-20',
#  '2022-08-21',
#  '2022-08-22',
#  '2022-08-23',
#  '2022-08-24',
#  '2022-08-25',
#  '2022-08-26',
#  '2022-08-27',
#  '2022-08-28',
#  '2022-08-29',
#  '2022-08-30',
#  '2022-08-31',
#  '2022-09-01',
#  '2022-09-02',
#  '2022-09-03',
#  '2022-09-04',
#  '2022-09-05',
#  '2022-09-06',
#  '2022-09-07',
#  '2022-09-08',
#  '2022-09-09',
#  '2022-09-10',
#  '2022-09-11',
#  '2022-09-12',
#  '2022-09-13',
#  '2022-09-14',
#  '2022-09-15',
#  '2022-09-16',
#  '2022-09-17',
#  '2022-09-18',
#  '2022-09-19',
#  '2022-09-20',
#  '2022-09-21',
#  '2022-09-22',
#  '2022-09-23',
#  '2022-09-24',
#  '2022-09-25',
#  '2022-09-26',
#  '2022-09-27',
#  '2022-09-28',
#  '2022-09-29',
#  '2022-09-30',
#  '2022-10-01',
#  '2022-10-02',
#  '2022-10-03',
#  '2022-10-04',
#  '2022-10-05',
#  '2022-10-06',
#  '2022-10-07',
#  '2022-10-08',
#  '2022-10-09',
#  '2022-10-10',
#  '2022-10-11',
#  '2022-10-12',
#  '2022-10-13',
#  '2022-10-14',
#  '2022-10-15',
#  '2022-10-16',
#  '2022-10-17',
#  '2022-10-18',
#  '2022-10-19',
#  '2022-10-20',
#  '2022-10-21',
#  '2022-10-22',
#  '2022-10-23',
#  '2022-10-24',
#  '2022-10-25',
#  '2022-10-26',
#  ...]

# %%
def parse_date(datestring):
    """ Convert a date string into a pandas datetime object """
    return pd.to_datetime(datestring, format="%Y-%m-%d")

# %%
start_date = parse_date(dates[0])
end_date = parse_date(dates[-1])
print(start_date,' to ',end_date)
# Out:
# 2020-01-31 00:00:00  to  2022-12-01 00:00:00

# %%
index = pd.date_range(start_date, end_date, freq='D')
Englandnewcasesandtestsdf=pd.DataFrame(index = index, columns = ['NewCasesByPublishDate', 'PCRTestsByPublishDate'])
Englandnewcasesandtestsdf
# Out:
#            NewCasesByPublishDate PCRTestsByPublishDate
# 2020-01-31                   NaN                   NaN
# 2020-02-01                   NaN                   NaN
# 2020-02-02                   NaN                   NaN
# 2020-02-03                   NaN                   NaN
# 2020-02-04                   NaN                   NaN
# ...                          ...                   ...
# 2022-11-27                   NaN                   NaN
# 2022-11-28                   NaN                   NaN
# 2022-11-29                   NaN                   NaN
# 2022-11-30                   NaN                   NaN
# 2022-12-01                   NaN                   NaN
#
# [1036 rows x 2 columns]

# %%
for entry in data_list:
    date = parse_date(entry['date'])
    for column in ['NewCasesByPublishDate', 'PCRTestsByPublishDate']:
        if pd.isna(Englandnewcasesandtestsdf.loc[date, column]):
            value = float(entry[column]) if entry[column]!=None else 0.0
            Englandnewcasesandtestsdf.loc[date,column]=value

Englandnewcasesandtestsdf.fillna(0.0, inplace=True)

Englandnewcasesandtestsdf
# Out:
#             NewCasesByPublishDate  PCRTestsByPublishDate
# 2020-01-31                    2.0                    0.0
# 2020-02-01                    0.0                    0.0
# 2020-02-02                    0.0                    0.0
# 2020-02-03                    0.0                    0.0
# 2020-02-04                    0.0                    0.0
# ...                           ...                    ...
# 2022-11-27                    0.0            173319956.0
# 2022-11-28                    0.0            173337231.0
# 2022-11-29                    0.0            173358841.0
# 2022-11-30                    0.0                    0.0
# 2022-12-01                22375.0                    0.0
#
# [1036 rows x 2 columns]

# %% [markdown]
# ## Download current data

# %% [markdown]
# The fucntions below gives users an option to refresh the dataset - a "refresh" button will do. The button callback will
# * call the code that accesses the API and download some fresh raw data;
# * wrangle that data into a dataframe and update the corresponding (global) variable for plotting;
# * optionally: force a redraw of the graph and give the user some fredback.

# %%
def wrangle_data(rawdata):
    """ Parameters: rawdata - data from json file or API call. Returns a dataframe.
    Edit to include the code that wrangles the data, creates the dataframe and fills it in. """
    df=pd.DataFrame(index=index, columns=['NewCasesByPublishDate', 'newCasesByPublishDate'])
    for entry in data_list:
        date = parse_date(entry['date'])
        for column in ['NewCasesByPublishDate', 'PCRTestsByPublishDate']:
            if pd.isna(Englandnewcasesandtestsdf.loc[date, column]):
                value = float(entry[column]) if entry[column]!=None else 0.0
                Englandnewcasesandtestsdf.loc[date,column]=value
    return df

df=wrangle_data(jsondata)

# %%
def access_api():
    """ Accesses the PHE API. Returns raw data in the same format as data loaded from the "canned" JSON file. """
    return {}

def access_api(button):
    filters = [
    'areaType=nation', 
    'areaName=England'
    ]
    structure = {
    "date": "date",
    "NewCasesByPublishDate":"newCasesByPublishDate",
    "PCRTestsByPublishDate":"cumPCRTestsByPublishDate"
    }
    api = Cov19API(filters=filters, structure=structure)

    Englandnewcasesandtests = api.get_json()
    apidata=access_api(Englandnewcasesandtests)
    
    global df
    df=wrangle_data(apidata)
    refresh_graph()
    apibutton.icon="check"
    #apibutton.disabled=True
   
apibutton=wdg.Button(
    description='Refresh data',
    disabled=False,
    button_style='success', # 'success', 'info', 'warning', 'danger' or ''
    tooltip='Click to download current Public Health England data',
    icon='download' # (FontAwesome names without the `fa-` prefix)
)

apibutton.on_click(access_api)

display(apibutton)
# Out:
# Button(button_style='success', description='Refresh data', icon='download', style=ButtonStyle(), tooltip='Clic…

# %% [markdown]
# ## Graphs and Analysis

# %% [markdown]
# The graph below shows the data for England's new cases and tests by publish date and the user can click on the interactive controls to view data for either data.

# %%
Englandnewcasesandtestsdf=pd.read_pickle("Englandnewcasesandtestsdf.pkl")

# %%
series=wdg.SelectMultiple(
    options=['NewCasesByPublishDate', 'PCRTestsByPublishDate'],
    value=['NewCasesByPublishDate', 'PCRTestsByPublishDate'],
    rows=2,
    description='Stats:',
    disabled=False
)

scale=wdg.RadioButtons(
    options=['linear', 'log'],
#    value='pineapple', # Defaults to 'pineapple'
#    layout={'width': 'max-content'}, # If the items' names are long
    description='Scale:',
    disabled=False
)

# try replacing HBox with a VBox
controls=wdg.HBox([series, scale])

def newcasesandtests_graph(gcols, gscale):
    if gscale=='linear':
        logscale=False
    else:
        logscale=True
    ncols=len(gcols)
    if ncols>0:
        Englandnewcasesandtestsdf[list(gcols)].plot(logy=logscale)
        plt.show() # important - graphs won't update if this is missing 
    else:
        print("Click to select data for graph")
        print("(CTRL-Click to select more than one category)")

# keep calling timeseries_graph(gcols=value_of_series, gscale=value_of_scale); 
# capture output in widget graph   
graph=wdg.interactive_output(newcasesandtests_graph, {'gcols': series, 'gscale': scale})

display(controls, graph)
# Out:
# HBox(children=(SelectMultiple(description='Stats:', index=(0, 1), options=('NewCasesByPublishDate', 'PCRTestsB…
# Output()

# %%
ctrls=wdg.VBox([series, scale])

form=wdg.HBox([graph, ctrls])

display(form)
# Out:
# HBox(children=(Output(), VBox(children=(SelectMultiple(description='Stats:', index=(0, 1), options=('NewCasesB…
